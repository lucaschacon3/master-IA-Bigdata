# %% [markdown]
# ### Introducción y Funcionamiento Interno
#
# **Libro recomendado:** [Think Python — Think Python](https://allendowney.github.io/ThinkPython/)
#
# ### Lenguaje Interpretado, de Alto Nivel y Orientado a Objetos
#
# Python es un lenguaje de **alto nivel** porque abstrae al programador de los detalles complejos del hardware y la gestión de memoria. Es **orientado a objetos** (casi todo son objetos en Python). Y es **interpretado**, lo que significa que el código se ejecuta línea por línea por un intérprete, en lugar de compilarse directamente a código máquina como C o C++.
#
# ### El Proceso: Código Fuente → Bytecode → CPython
#
# Aunque Python es interpretado, internamente realiza un proceso de compilación para optimizar la ejecución.
#
# 1. **Código Fuente**: El programador escribe el código en un archivo `.py`.
# 2. **Análisis y AST (Abstract Syntax Tree)**: El intérprete (CPython) lee el código fuente y lo convierte en una estructura jerárquica llamada **Árbol de Sintaxis Abstracta**. Este paso verifica que la sintaxis sea correcta .
# 3. **Compilación a Bytecode**: El AST se compila a un lenguaje de más bajo nivel llamado **bytecode**. Este bytecode es un conjunto de instrucciones independientes de la plataforma y está diseñado para ser ejecutado de manera eficiente por una máquina virtual. Normalmente se guarda en archivos `.pyc` dentro de una carpeta `__pycache__` para acelerar ejecuciones futuras .
# 4. **Máquina Virtual (PVM)**: El bytecode se envía a la máquina virtual de Python, que es un gran bucle que itera sobre las instrucciones del bytecode y las ejecuta una por una. CPython actúa como una capa que traduce las instrucciones del bytecode a instrucciones que el sistema operativo y el hardware puedan entender.
#
# ### Compatibilidad con C y C++
#
# Python y C/C++ tienen una relación muy simbiótica a través de la **API Python/C**. Esta API permite dos cosas fundamentales :
#
# - **Escribir Módulos de Extensión**: Puedes escribir funciones y tipos en C o C++ que luego se pueden importar y usar en Python como si fueran módulos nativos. Esto es para optimizar partes del código (cuellos de botella) o para permitir que Python interactúe con librerías y hardware escritos en C/C++ (ej. librerías de gráficos, controladores de dispositivos).
# - **Integrar Python en una Aplicación**: Puedes incrustar el intérprete de Python dentro de una aplicación más grande escrita en C/C++. Esto permite que los usuarios extiendan la funcionalidad de la aplicación mediante scripts de Python (ej. software de modelado 3D como Blender, videojuegos).
#
# ### Tipado Dinámico y fuerte
#
# Es tipado dinámico porque el tipo de una variable no es necesario declararlo explícitamente, el tipo de la variable será igual al tipo del objeto que apunte. Una misma variable puede cambiar de tipo a lo largo del programa. Esto contrasta con lenguajes de tipado estático como Java, donde el tipo de una variable se declara y no puede cambiar.

# %%
print("hola" + 10)    # Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("hola" + 10)    # Error
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Es de tipado fuerte, porque prohíbe el uso de variables como tipos de datos distintos a los que fueron definidos. A diferencia del tipado débil (ej. JavaScript, PHP), donde `5 + "5"` puede resultar en `"55"` .

# %%
mi_variable = 10       
print(type(mi_variable)) # type(mi_variable) --> int
mi_variable = "Hola"   
print(type(mi_variable)) # type(mi_variable) --> str
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### Sectores de Aplicación en la Actualidad
#
# Python se ha convertido en un lenguaje “navaja suiza” gracias a su versatilidad:
#
# - **Desarrollo Web**: Con frameworks robustos como **Django** (para aplicaciones completas y seguras) y **Flask** o **FastAPI** (para APIs y microservicios ágiles) .
# - **Ciencia de Datos (Data Science)**: Es el lenguaje estándar. Se utiliza para limpiar, analizar y visualizar datos con librerías como **PySpark, Pandas, Polars, NumPy, Matplotlib o Seaborn**.
# - **Inteligencia Artificial y Machine Learning**: El ecosistema más potente del mercado. Frameworks como **TensorFlow, PyTorch, Keras, scikit-learn o XGBoost** están escritos principalmente para Python, convirtiéndolo en la lengua franca de la IA .
# - **Desarrollo de Videojuegos**: Aunque no es para juegos AAA de alto rendimiento, es excelente para prototipado rápido y desarrollo de juegos 2D con librerías como **Pygame** .
# - **Scripting y Automatización**: Ideal para escribir scripts que automaticen tareas repetitivas del sistema, como renombrar archivos, procesar texto, o interactuar con APIs web .
# - **Aplicaciones de Escritorio**: Mediante librerías como **Tkinter** (incluida), **PyQt** o **Kivy**.
# - **Internet de las Cosas (IoT)** y Robótica: Gracias a su simplicidad y a la potencia de placas como la **Raspberry Pi**, es muy usado para controlar sensores y motores .
#
# ### Instalación de Python y PIP
#
# Lo primero es instalar el intérprete de Python. Sigue las instrucciones para tu sistema operativo.
#
# - **Windows:** Descargar desde la web oficial
# - **macOS:** Trae Python preinstalado, no es recomendable usarlo para desarrollo. Lo mejor es instalar **Homebrew**, un gestor de paquetes para macOS. Abre la Terminal y pega:

# %%
# !brew install python3

# %% [markdown]
# - **Linux (Debian/Ubuntu)**
#
#     Las distribuciones Linux suelen incluir Python 3 por defecto.

# %%
# !sudo apt update
# !sudo apt install python3

# %% [markdown]
# Para comprobar si está instalado:

# %%
# !python3 --version
# Out:
# Python 3.12.3

# %% [markdown]
# Es necesario instalar pip para usar librerías externas, ya que python tiene librerías estándar que ya vienen instaladas como:
#
# - **os**: gestiona archivos, carpetas y rutas del sistema operativo.
# - **sys**: accede a parámetros del intérprete y argumentos de línea de comandos.
# - **datetime**: manipula fechas, horas y cálculos de tiempo.
# - **json**: convierte datos entre diccionarios de Python y formato JSON.
# - **csv**: Lectura y escritura de archivos en formato de valores separados por comas.
# - **math**: proporciona funciones matemáticas avanzadas y constantes como pi.
# - **random**: genera números pseudoaleatorios y realiza selecciones al azar.
# - **collections**: ofrece estructuras de datos optimizadas como `Counter` o `deque`.
#
# ### **Crear y Activar un Entorno Virtual**
#
# Un entorno virtual es una caja aislada para tu proyecto. Evita que las librerías de un proyecto interfieran con las de otro.
#
# 1. **Abrir terminal**
# 2. **Crear el entorno**

# %%
# !python3 -m venv .venv

# %% [markdown]
# Esto creará una carpeta llamada `.venv` que contendrá tu entorno virtual . Puedes llamarla como quieras pero esta es la forma normalizada, el “.” es para que sea carpeta oculta
#
# 3. **Activar el entorno**:

# %%
# !source venv/bin/activate

# %% [markdown]
# Verás que el nombre del entorno (`(venv)`) aparece al principio de la línea en tu terminal, lo que indica que está activado .
#
# ### Python 2 (pip) vs Python 3 (pip3)
#
# Python 2 dejó de tener soporte oficial. Siempre se debe usar Python 3.
#
# **El Comando `python` y `python3`**
#
# En muchos sistemas, especialmente Linux y macOS, pueden coexistir ambas versiones.
#
# - `python`: Suele estar enlazado a `python3`, en ocasiones podría apuntar a Python 2.
# - `python3`: Apunta a la versión 3 del intérprete. Es la forma más segura y recomendada de ejecutar scripts Python.
#
# **El Comando `pip` y `pip3`**
#
# - `pip`: En algunos sistemas, puede estar asociado a Python 2.
# - `pip3`: Asociado explícitamente a Python 3. Es el que se debe usar para instalar paquetes para Python 3.
#
# Aunque se pueda usar el comando `pip <comando>` o `pip3 <comando>` lo recomendable es usarlo así:

# %%
# !python3 -m pip --version
# Out:
# pip 24.0 from /home/lucas/Workspace/master-IA-Bigdata/.venv/lib/python3.12/site-packages/pip (python 3.12)

# %% [markdown]
# * Comandos comunes:
# ```bash
# python3 -m pip install <nombre_paquete>
# python3 -m pip uninstall <nombre_paquete>
# python3 -m pip list
#
# # paquetes con versiones antiguos
# python3 -m pip list outdated
#
# # Mostrar paquetes en formato requirements
# python3 -m pip freeze
#
# #Vuelca los paquetes en requirements.txt
# python3 -m pip freeze > requirements.txt
#
# # Instalar los paquetes de un archivo
# python3 -m pip install -r requirements.txt
# ```
#
# La “-m” es de módulo y la “-r” de requirements.

# %% [markdown]
# ### Entornos de Desarrollo y Herramientas
#
# ### IDEs
#
# **Visual Studio Code (VS Code)** se ha convertido en uno de los editores más populares para Python. Con la extensión oficial de Python (de Microsoft), ofrece:
#
# - Autocompletado inteligente (IntelliSense).
# - Depuración integrada.
# - Soporte para Jupyter Notebooks.
# - Gestión integrada de entornos virtuales y Git .
#
# También se usa **PyCharm** de JetBrains y **Google Colab** que puedes guardar en la nube las ejecuciones usando poder computacional de google (útil en el desarrollo de IA).
#
# ### Alternativas Potentes: Conda, Jupyter y Anaconda
#
# - **Anaconda**: Es una distribución de Python (y R) que incluye el intérprete, más de 1500 paquetes científicos preinstalados (Pandas, NumPy, etc.) y un gestor de paquetes y entornos llamado `conda`. Es enorme, pero muy útil para ciencia de datos.
# - **Miniconda**: Una versión ligera de Anaconda que incluye solo `conda` y Python. Luego puedes instalar solo los paquetes que necesites .
# - **Conda**: Es el gestor de paquetes y entornos de Anaconda. Es más poderoso que `pip`+`venv` porque no solo gestiona paquetes de Python, sino también librerías de otros lenguajes (como C) de las que dependen muchos paquetes científicos.
# - **Jupyter Notebook / Jupyter Lab**: Es una aplicación web de código abierto que permite crear y compartir documentos que contienen código en vivo, ecuaciones, visualizaciones y texto narrativo. Es la herramienta estrella para Data Science, ya que permite experimentar de forma interactiva . Jupyter Lab es la evolución de Jupyter Notebook, con una interfaz más moderna y flexible.
